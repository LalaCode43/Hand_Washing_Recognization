# %%
from lib import *

# %%
data = pd.read_csv('./result/14_6_2021/mobilenet_logs.csv')
data
# Out:
#     Unnamed: 0  epoch  train_loss  train_acc  val_loss   val_acc
# 0            0      0    1.025515   0.626946  0.669323  0.770380
# 1            1      1    0.597325   0.797403  0.542398  0.816422
# 2            2      2    0.502386   0.831093  0.472952  0.841159
# 3            3      3    0.444596   0.851006  0.428418  0.857316
# 4            4      4    0.400789   0.865608  0.393967  0.867898
# 5            5      5    0.368096   0.876107  0.369635  0.876138
# 6            6      6    0.339425   0.885581  0.342759  0.884152
# 7            7      7    0.317145   0.892450  0.332380  0.888339
# 8            8      8    0.298201   0.898985  0.311813  0.894784
# 9            9      9    0.279238   0.905034  0.295810  0.899421
# 10          10     10    0.264436   0.910418  0.269439  0.908506
# 11          11     11    0.249871   0.914848  0.267274  0.909474
# 12          12     12    0.273163   0.907338  0.250753  0.915456
# ...

# %%
data = pd.read_csv('./result/14_6_2021/mobilenet_logs.csv').values

train_loss = data[:, 2] 
train_acc = data[:, 3]

val_loss = data[:, 4]
val_acc = data[:, 5]
fig_loss = plt.figure(figsize=(8, 5))
plt.plot(train_loss, label='train_loss')
plt.plot(val_loss, label='val_loss')
plt.xlabel('Train Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.grid(True)

# %%
fig_acc = plt.figure(figsize=(8, 5))
plt.plot(train_acc, label='train_acc')
plt.plot(val_acc, label='val_acc')
plt.xlabel('Train Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# %%
cnf_matrix =np.array([[24143.,   929.,   285.,   296.,   198.,   296.,   217.],
                            [ 2729.,  9145.,   158.,   668.,   137.,    36.,   123.],
                            [ 2005.,   370., 10408.,   688.,    48.,   127.,    59.],
                            [ 1578.,  1017.,   336.,  4180.,    75.,    68.,    42.],
                            [ 1353.,    59.,    67.,    46.,  4193.,   171.,   226.],
                            [ 1829.,    50.,   118.,   130.,   256.,  3838.,   324.],
                            [ 1402.,   330.,    83.,   237.,   173.,   140.,  3794.]])

# %%
from utils import  *
num_classes = 7
class_names = range(num_classes)
fig = plt.figure(figsize=(10, 8))
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Hand Washing Recognization')

plt.show()

# %%
fig.savefig('./result/14_6_2021/figs/cnf_matrix.jpg', format='jpg', dpi=1200)

# %%
fig_loss.savefig('./result/14_6_2021/figs/loss.eps', format='eps', dpi=1200)
fig_acc.savefig('./result/14_6_2021/figs/acc.eps', format='eps', dpi=1200)
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fig_acc
